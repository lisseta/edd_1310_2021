# %% [markdown]
# <a href="https://colab.research.google.com/github/lisseta/edd_1310_2021/blob/master/M24_Noviembre_1310.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class NodoDoble:
    def _init_ (self, value, anterior = None , siguiente = None):
        self.data = value
        self.siguiente = siguiente
        self.anterior = anterior
class DoubleLinkedList:
    def _init_ (self):
        self.__head = NodoDoble (None)
        self.__tail = NodoDoble (None)
        self.__size = 0

    def get_size (self):
        return self.__size
    
    def is_empty (self):
        return self.__size == 0

    def append (self, value):
        if self.is_empty():
            nuevo = NodoDoble(value)
            self.__head = nuevo
            self.__tail = nuevo
        else:
            nuevo = NodoDoble(value, self.__tail, None)
            self.__tail.siguiente = nuevo
            self.__tail = nuevo
        self.__size += 1

    def transversal (self):
            curr_node = self.__head
            while curr_node != None:
                print (f"<-- { curr_node.data } --> ", end = "")
                curr_node = curr_node.siguiente
            print("")

    def reverse_transversal(self):
            curr_node = self.__tail
            while curr_node != None:
                print (f"<-- { curr_node.data } --> ", end = "")
                curr_node = curr_node.anterior
            print("")        

    def remove_from_head(self, value): 
        curr_node = self.__head
        while curr_node.data != value and curr_node != None:
            curr_node = curr_node.siguiente
        if curr_node.data == value:
            curr_node.anterior.siguiente = curr_node.siguiente
            curr_node.siguiente.anterior = curr_node.anterior
        curr_node.siguiente = None
        curr_node.anterior = None
        self.__size -= 1

# %%
#Linea 39 

self.__head=self.__head.siguiente
else:
  anterior=Nonewhile curr_none.data != value and curr_node.siguiente
  curr_node=curr_node.siguiente






#Linea 99
def reverse_transversal(self):
  curr_node=self.__tail
  while curr_node != None:
    print(f"<-- {curr_node.data} -->" , #Aqui falta algo)
    curr_node=curr_node-prev
    print("")


def remove from_head(self,value):
  curr_node=self.__head
  while curr_node.data != value and curr_node != None
  curr_node=curr_node.next
  if curr_node.data==value:
    


#Linea 105
def remove from_head(self,value):
  curr_node=self.__head
  if self.__head.data==value:

    while curr_node.data != value and curr_node != None:
      curr_node=curr_node.next
    if curr_node.data==value:
      curr_node.prev.next =curr_node.next
      curr_node.nextr.prev =curr_node.prev

# %%
class Nodo:

class LinkedList:



class DoubleLinkedList:
  def __init__(self):
    self.__head=None
    self.__tail=None
    self.__size=0

  def get:size(self):
    return self.__size

  def is_empty(self):
    return self.__size==0
    
  def append(self , value):
    if self.is_empty():
      nuevo=NodoDoble(value)
      self.__tail.next=nuevo
      self.__tail=nuevo 

  def transversal(self):
    curr_node=self.__head
    while curr_node !=None:
      print(f"{ curr_node.data} -->" , end="")
      curr_node=curr_node.next






def remove (self,value):
  curr_node=self.__head
  if self.__head.data == value:
    self.__head=self.__head.siguiente
  else:
    anterior=None
    while curr_node.data  != value and curr_node.siguiente
    anterior =curr_node
    curr_node= curr_node.siguiente
    if curr_node.data == value:
      anterior.siguiente=curr_node.siguiente

  

  
  











class NodoDoble:
  def__init__(self,value,siguiente=None):
    self.data=value
    self.next=siguiente
    self.prev=anterior

 class DoubleLinkedList:
 def__init__(self):
   self.__head=None
   self.__tail=None
   self.__size=0

  def get_size(self):
    return self.__size

  def is_empty(elf):
    return self.__size==0

  def append(self, value)
  if self.is_empty():
    nuevo=NodoDoble(value)
    self.__head=nuevo
    self.__tail=nuevo
  else:  
    nuevo=NodoDoble(value, self.__tail, None)
    self.__tail.siguiente=nuevo
    selt.tail=nuevo

def transversal(self):
  curr_node=self.__head
  while curr_node != None:
    print(f"{ curr_node.data} --> ", end="")
    curr_node=curr_node.next

   

def reverse_transversal(self):
  curr_node=self.__tail
  while curr_node != None:
    print(f"<-- {curr_node.data} -->" , #Aqui falta algo)
    curr_node=curr_node-prev
    print("")
def remove from_head(self,value):
  curr_node=self.__head
  while curr_node.data != value and curr_node != None
  curr_node=curr_node.next
  if curr_node.data==value:







def is_empty(self):
  return self.size==0

def append(self,value):
  if self.is_empty():
    nuevo=NodoDoble(value)
    self.head=nuevo
    self.tail=nuevo
  else:
    nuevo=NodoDoble(value,self.__tail, None)    
    self.__tail.next=nuevo 
    self.__tail=nuevo

def transveral(self):
  curr_node=self.__head
  while curr_node != None:
    print(f"{curr_node.data} --> " , end="")
    curr_node=curr


def remove from_head(self,value):
  curr_node=self.__head
  if self.__head.data==value:

    while curr_node.data != value and curr_node != None:
      curr_node=curr_node.next
    if curr_node.data==value:
      curr_node.prev.next =curr_node.next
      curr_node.nextr.prev =curr_node.prev























def remove from_head(self,value):
  curr_node=self.__head
  if self.__head.data==value:

    while curr_node.data != value and curr_node != None:
      curr_node=curr_node.next
    if curr_node.data==value:
      curr_node.prev.next =curr_node.next
      curr_node.nextr.prev =curr_node.prev

# %%
def reverse_transversal(self):
  curr_node=self.__tail
  while curr_node != None:
    print(f"<-- {curr_node.data} -->", end="")
    curr_node=curr

# %% [markdown]
# #Entorno de Ejecuciòn
# Podemos hacer pruebas

# %%
from listas import DoubleLinkedList

ld = DoubleLinkedList() #<- CONSTRUCTOR
print("¿Esta vacia?", ls.is_empty() )
ld.append(10)
ld.append(20)
ld.append(30)

print(f"La lista tiene { ld.get_size() } elementos")
ld.transversal()
ld.reverse_transversal()
